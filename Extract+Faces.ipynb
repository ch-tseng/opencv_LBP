# %%
import numpy as np
import cv2 as cv
import glob
sourePath = "dataset/source"
savePath = "dataset/face"

face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('haarcascade_eye.xml')

# %%
i = 0

for filePath in glob.glob(sourePath+"/*"):
    print("Load {} ...".format(filePath))
    
    img = cv.imread(filePath)
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:
        #cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        cv.imwrite(savePath+"/face-"+str(i)+".jpg", roi_color)
        i+=1
# Out:
# Load dataset/source/DSCF3570.JPG ...
# Load dataset/source/20160719_163309.jpg ...
# Load dataset/source/DSCF3484.jpg ...
# Load dataset/source/DSCF3673.JPG ...
# Load dataset/source/DSCF3691.JPG ...
# Load dataset/source/DSCF3671.JPG ...
# Load dataset/source/16-10-18-16-17-18-259_deco.jpg ...
# Load dataset/source/DSCF3546.JPG ...
# Load dataset/source/DSCF3658.JPG ...
# Load dataset/source/16-06-21-16-37-50-693_deco.jpg ...
# Load dataset/source/16-08-16-16-40-14-423_deco.jpg ...
# Load dataset/source/DSCF3510.jpg ...
# Load dataset/source/20161117_160458.jpg ...
# Load dataset/source/20160719_161010.jpg ...
# Load dataset/source/20160816_161146.jpg ...
# Load dataset/source/DSCF3620.JPG ...
# Load dataset/source/DSCF3582.JPG ...
# Load dataset/source/DSCF3590.JPG ...
# Load dataset/source/DSCF3557.JPG ...
# Load dataset/source/DSCF3586.JPG ...
# Load dataset/source/DSCF3747.JPG ...
# Load dataset/source/20160719_163318.jpg ...
# Load dataset/source/20161018_162837.jpg ...
# ...

# %%
def putText(img, txt=""):
font                   = cv2.FONT_HERSHEY_SIMPLEX
bottomLeftCornerOfText = (10,500)
fontScale              = 1
fontColor              = (255,255,255)
lineType               = 2

cv2.putText(img,'Hello World!', 
    bottomLeftCornerOfText, 
    font, 
    fontScale,
    fontColor,
    lineType)

# %%
img = "dataset/facetest/DSC09915.jpg"
from matplotlib import pyplot as plt
# Plot inline
# %matplotlib inline

image = cv.imread(img)
b,g ,r = cv.split(image)
image = cv.merge([r,g,b])
plt.figure(figsize=(12, 8))

plt.imshow(image)
